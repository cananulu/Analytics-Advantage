# %% [markdown]
# <a href="https://colab.research.google.com/github/cananulu/Analytics-Advantage/blob/claude%2Fcustomer-insights-dashboard-YqdN8/CustomerDashboard.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/cananulu/Analytics-Advantage.git
# %cd Analytics-Advantage
# !git checkout claude/customer-insights-dashboard-YqdN8
# !pip install pandas
# Out:
# Cloning into 'Analytics-Advantage'...
# fatal: could not read Username for 'https://github.com': No such device or address
# [Errno 2] No such file or directory: 'Analytics-Advantage'
# /content
# fatal: not a git repository (or any of the parent directories): .git
# ...

# %%
# !python3 generate_sample_data.py
# !python3 generate_dashboard.py

# %%
from google.colab import files
files.download('dashboard/index.html')
